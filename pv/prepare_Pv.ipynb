# %%
from PIL import Image, ImageFont, ImageDraw, ImageEnhance
import requests
from io import BytesIO
import json
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from skimage.filters import threshold_otsu
from skimage.io import imread, imsave
from skimage.color import rgb2gray
from skimage.measure import label, regionprops
from skimage.transform import rescale, resize, downscale_local_mean
import random
import math
import imageio
import imgaug as ia
from imgaug import augmenters as iaa
from imgaug.augmentables.bbs import BoundingBox, BoundingBoxesOnImage
import glob
import random
import shutil

# %%
count = 41
files = glob.glob('001/*.jpg')
for file in files:
    os.rename(file,"tmp_iamges/pv-{:010d}.jpg".format(count))
    count += 1

# %%
files = glob.glob('002/*.jpg')
for file in files:
    os.rename(file,"tmp_iamges/pv-{:010d}.jpg".format(count))
    count += 1

# %%
files = glob.glob('003/*.jpg')
for file in files:
    os.rename(file,"tmp_iamges/pv-{:010d}.jpg".format(count))
    count += 1

# %%
files = glob.glob('007/*.jpg')
for file in files:
    os.rename(file,"tmp_iamges/pv-{:010d}.jpg".format(count))
    count += 1

# %%
files = glob.glob('008/*.jpg')
for file in files:
    os.rename(file,"tmp_iamges/pv-{:010d}.jpg".format(count))
    count += 1

# %%
files = glob.glob('009/*.jpg')
for file in files:
    os.rename(file,"tmp_iamges/pv-{:010d}.jpg".format(count))
    count += 1

# %%
files = glob.glob('010/*.jpg')
for file in files:
    os.rename(file,"tmp_iamges/pv-{:010d}.jpg".format(count))
    count += 1

# %%
files = glob.glob('011/*.jpg')
for file in files:
    os.rename(file,"tmp_iamges/pv-{:010d}.jpg".format(count))
    count += 1

# %%
# gen url
count = 41
for i in range(count,825):
    name = "pv-{:010d}.jpg".format(i)
    print("https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Vivax/"+name)
# Out:
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Vivax/pv-0000000041.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Vivax/pv-0000000042.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Vivax/pv-0000000043.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Vivax/pv-0000000044.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Vivax/pv-0000000045.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Vivax/pv-0000000046.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Vivax/pv-0000000047.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Vivax/pv-0000000048.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Vivax/pv-0000000049.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Vivax/pv-0000000050.jpg
# https://raw.githubusercontent.com/RTANC/malaria_dataset/master/Vivax/pv-0000000051.jpg
# ...

# %%
count = 15250
for i in range(count,15367):
    name = "{:010d}".format(i)
    print(name)
    os.remove(os.path.join("images/",name+".jpg"))
    os.remove(os.path.join("labels/",name+".txt"))
